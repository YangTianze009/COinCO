# %%
import sys
sys.executable

# %%
import sys, os
sys.path.append(os.path.join(os.path.abspath(''), '..', '..'))
import config

os.getcwd()

# %%
import pandas as pd

# %%
df_Part1_1 = pd.read_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part1.csv'))
df_Part1_2 = pd.read_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part1_continue.csv'))
df_Part2_1 = pd.read_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part2.csv'))
df_Part2_2 = pd.read_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part2_continue.csv'))

# %%
df_combined_1 = pd.concat([df_Part1_1, df_Part1_2])
df_combined_1

# %%
df_combined_2 = pd.concat([df_Part2_1, df_Part2_2])
df_combined_2

# %%
df_combined_1.to_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part1_combined.csv'))

# %%
df_combined_2.to_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl_part2_combined.csv'))

# %%
df = pd.concat([df_combined_1, df_combined_2], ignore_index=True)
df

# %%
df.to_csv(os.path.join(config.CONTEXT_REASONING_RES_DIR, 'internvl', 'context_reasoning_internvl.csv'))
